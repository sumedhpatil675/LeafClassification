# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pickle
import random
from sklearn.model_selection import train_test_split 
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC 
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pick_in2 =open('/content/drive/MyDrive/FinalYear_Project/pickles_dataset/swedishReduced.pickle','rb')
data =pickle.load(pick_in2)
pick_in2.close()

# %%
data

# %%
import random
random.shuffle(data)
features = []
labels = []

for feature,label in data:
  features.append(feature)
  labels.append(label)

# %%
features

# %%
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.15)

# %%
#Training GaussianNaiveBayes on Best fitted Parameters


#Create a svm Classifier
clf = GaussianNB()

clf.fit(X_train,y_train)



y_pred = clf.predict(X_test)
acc_naivaBayes = round(accuracy_score(y_pred, y_test) * 100, 2)
print("MODEL-3: Accuracy of NaiveBayes : ", acc_naivaBayes)

precision, recall, fscore, support = score(y_test, y_pred)

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
# Out:
# MODEL-3: Accuracy of NaiveBayes :  76.33
# precision: [0.91666667 0.875      1.         0.66666667 0.75       1.
#  0.8125     1.         0.625      0.66666667 1.         0.90909091
#  0.33333333 0.47058824 0.58333333]
# recall: [0.6875     0.77777778 1.         0.6        0.92307692 0.86666667
#  1.         1.         0.41666667 0.8        1.         0.71428571
#  0.75       0.57142857 0.53846154]
# fscore: [0.78571429 0.82352941 1.         0.63157895 0.82758621 0.92857143
#  0.89655172 1.         0.5        0.72727273 1.         0.8
#  0.46153846 0.51612903 0.56      ]
